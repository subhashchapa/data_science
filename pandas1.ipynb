# %% [markdown]
# <a href="https://colab.research.google.com/github/subhashchapa/data_science/blob/main/pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# main difference between numpy array and pandas series is
#
# --->numpy array contain number index
#
# --->pandas series contain labeled index

# %%
import numpy as np
import pandas as pd

# %%
#help(pd.Series)

# %% [markdown]
# Series contain both data and index.so we make two different lists and then convert them into pandas Series

# %%
myindex=['USA','CANADA','MEXICO']  #

# %%
mydata=[1776,1867,1821]

# %%
myser=pd.Series(data=mydata)

# %%
myser
# Out:
# 0    1776
# 1    1867
# 2    1821
# dtype: int64

# %%
type(myser)
# Out:
# pandas.core.series.Series

# %%
myser=pd.Series(data=mydata,index=myindex)

# %%
myser
# Out:
# USA       1776
# CANADA    1867
# MEXICO    1821
# dtype: int64

# %%
myser[0]
# Out:
# 1776

# %%
myser['USA']
# Out:
# 1776

# %%
myser=pd.Series(mydata,myindex) #no need for explicit mention if they are in correct order

# %%
myser
# Out:
# USA       1776
# CANADA    1867
# MEXICO    1821
# dtype: int64

# %% [markdown]
# converting dictionary to pandas Series

# %%
ages={'subhash':1,'hanok':323,'satya':3423}

# %%
pd.Series(ages)
# Out:
# subhash       1
# hanok       323
# satya      3423
# dtype: int64

# %%
S1={'subhash':1,'hanok':323,'satya':986,'srinu':1783}
S2={'subhash':2,'hanok':32,'sai':98,'srinu':175}

# %%
S1
# Out:
# {'hanok': 323, 'satya': 986, 'srinu': 1783, 'subhash': 1}

# %%
S2
# Out:
# {'hanok': 32, 'sai': 98, 'srinu': 175, 'subhash': 2}

# %%
gate1=pd.Series(S1)
gate2=pd.Series(S2)

# %%
gate1
# Out:
# subhash       1
# hanok       323
# satya       986
# srinu      1783
# dtype: int64

# %%
gate2
# Out:
# subhash      2
# hanok       32
# sai         98
# srinu      175
# dtype: int64

# %%
gate1['subhash']   #index must be case sensitive
# Out:
# 1

# %%
gate1.keys()   #for knowing keys
# Out:
# Index(['subhash', 'hanok', 'satya', 'srinu'], dtype='object')

# %% [markdown]
# pandas is built on numpy arrays. so we can perform broadcast operation.

# %%
np.array([1,2])*3
# Out:
# array([3, 6])

# %%
gate1/2
# Out:
# subhash      0.5
# hanok      161.5
# satya      493.0
# srinu      891.5
# dtype: float64

# %%
gate1*3
# Out:
# subhash       3
# hanok       969
# satya      2958
# srinu      5349
# dtype: int64

# %% [markdown]
# when performing operation between two series then by default labeled index is taken into consideration

# %%
gate1+gate2   #if the elements are not common then it shows NaN

# %%
gate
# Out:
# hanok       355.0
# sai           NaN
# satya         NaN
# srinu      1958.0
# subhash       3.0
# dtype: float64

# %%
gate=gate1.add(gate2,fill_value=0)  #return the values into floats

# %%
gate.dtype
# Out:
# dtype('float64')

# %%
gate.astype(int)   #for changing the data type
# Out:
# hanok       355
# sai          98
# satya       986
# srinu      1958
# subhash       3
# dtype: int64

# %% [markdown]
# **DATA FRAMES**
# -->A datafram is a table of columns and rows in pandas that we can easily restructure and filter
#
# -->fd  :A group of pandas series objects that share the same index

# %% [markdown]
# ![dataframe.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (1552).png](data:image/png;base64,...)

# %% [markdown]
# **Continuation in next notebook**
